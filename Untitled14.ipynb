# %% [markdown]
# <a href="https://colab.research.google.com/github/7009soham/CARGO/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
weather = pd.read_csv("WeatherData.csv")
